# %%
print(123)
# Out:
# 123

# %%
x=12.2
y=14
print(x)
print(x,y)
print("X:",x, "Y:",y)
print("X:"+str(x), "Y:"+str(y))
x=x+10
print(x)
# Out:
# 12.2
# 12.2 14
# X: 12.2 Y: 14
# X:12.2 Y:14
# 22.2

# %%
PI=3.14
radius=input("Enter the value of radius: ")
area=PI*float(radius)**2
print("The area is: ",area)
# Out:
# Enter the value of radius: 5
# The area is:  78.5

# %%
a=10
b=20
a,b=b,a
print("a:",a,"b:",b)
# Out:
# a: 20 b: 10

# %%
P=input("Enter the principal:")
R=input("Rate of interest:")
T=input("Input times (In year)")
Interest=(float(P)*float(R)*float(T))/100
print("Interest: ",Interest)
# Out:
# Enter the principal:5
# Rate of interest:6
# Input times (In year)7
# Interest:  2.1

# %%
celcius=37
Farenheit=(float(celcius)*9/5)+32
print("Farenheit:",Farenheit)
# Out:
# Farenheit: 98.6

# %%
length=input("Enter the length:")
width=input("Enter the width:")
Area=int(length)*int(width)
print("Area:",area)
Perimeter=(float(length)+float(width))/2
print("Perimeter:",Perimeter)
# Out:
# Enter the length:2
# Enter the width:5
# Area: 78.5
# Perimeter: 3.5

# %%
print(type(12.3))
print(type("Mustakim"))
print(type(12))
# Out:
# <class 'float'>
# <class 'str'>
# <class 'int'>

# %%
noun = 'David'
day = 'Monday'
str = f'''how are you Mr , {noun}. You are invited to come to my home on {day}.
{noun} don't miss the chance'''
print(str)
# Out:
# how are you Mr , David. You are invited to come to my home on Monday.
# David don't miss the chance

# %%
hour=input("Enter hour:")
rate=input("Enter rate:")
pay=float(hour)*float(rate)
print(pay)
# Out:
# Enter hour:5
# Enter rate:6
# 30.0

# %%
print(n=7)
print(7+5)
print(5.2,'this',4-2,'that',5/2.0)
# Out:
# 12
# 5.2 this 2 that 2.5

# %%
a,b,c,d,e,f,g,h,i,j='All' ,'work' ,'and' ,'no' ,'play', 'makes', 'Jack', 'a', 'dull','boy.'
print(a+' '+b+' '+c+' '+d+' '+e+' '+f+' '+g+' '+h+' '+i+' '+j)
# Out:
# All work and no play makes Jack a dull boy.

# %%
x=6*1-2-10
print(x)
# Out:
# -6

# %%
#This is comment m=5
print(m) #Comment cannot be written in the beginning of any line in coding
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-175e793ecc85> in <cell line: 2>()
#       1 #This is comment m=5
# ----> 2 print(m) #Comment cannot be written in the beginning of any line in coding
#
# NameError: name 'm' is not defined

# %%
x=input()
float(x)
print(x)

y=raw_input()
str(y)
print(y)
# Out:
# 3.14
# 3.14
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-d35d85886189> in <cell line: 5>()
#       3 print(x)
#       4
# ----> 5 y=raw_input()
#       6 str(y)
#       7 print(y)
#
# NameError: name 'raw_input' is not defined

# %%
bruce=6
bruce+=4
print(bruce)
# Out:
# 10

# %%
noun=input("Enter a noun:")
verb=input("Enter a verb")
adjective=input("Enter an adjective:")
adverb=input("Enter an adverb:")
pluralNouns=input("Enter a plural Noun:")
pastTense=input("Enter past tense verb")
str=f'''Hey, {noun}. {verb} {adjective} {adverb} {pluralNouns} {pastTense}'''
print(str)
# Out:
# Enter a noun:Taaha
# Enter a verbgo
# Enter an adjective:good
# Enter an adverb:very
# Enter a plural Noun:friends
# Enter past tense verbwent
# Hey, Taaha. go good very friends went
