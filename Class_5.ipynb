# %%
def facto():
  n=int(input('Enter a number: '))
  fact=1
  for i in range(1,n+1,1):
    fact*=i
  print(fact)

facto()
# Out:
# Enter a number: 5
# 120

# %%
n=1245
if n==int(str(n)[::-1]):
  print('Pallindrome Number')
else:
  print('Not Pallindrome')
# Out:
# Not Pallindrome

# %%
#practice 1
def great(a,b,c):
  if a>b:
    if a>c:
      print(a)
      print('A')
    else:
      print(b)
      print('B')
  else:
     if b>c:
      print(b)
      print('B')
     else:
      print(c)
      print('C')

a=int(input('Enter a number: '))
b=int(input('Enter a number: '))
c=int(input('Enter a number: '))
great(a,b,c)
# Out:
# Enter a number: 10
# Enter a number: 20
# Enter a number: 35
# 35
# C

# %%
#practice 2
def table(a):
  for i in range(10,0,-1):
    print(a," X ",i," = ",a*i)
n=int(input('Enter a number: '))
table(n)
# Out:
# Enter a number: 8
# 8  X  10  =  80
# 8  X  9  =  72
# 8  X  8  =  64
# 8  X  7  =  56
# 8  X  6  =  48
# 8  X  5  =  40
# 8  X  4  =  32
# 8  X  3  =  24
# 8  X  2  =  16
# 8  X  1  =  8

# %%
#Exercise 1
def carea(a):
  area=a*a*3.1416
  #print("Area of the circle is: ",area)
  return area

def sarea(a):
  print("Area of the circle is: ",a*a)

a=int(input('Enter the radius of a Circle: '))
m=carea(a)
print(m)
b=int(input('Enter the length of a Square: '))
sarea(b)
# Out:
# Enter the radius of a Circle: 5
# 78.53999999999999
# Enter the length of a Square: 5
# Area of the circle is:  25

# %%
#Exercise 2
def count(a):
  sum=0
  for i in a:
    sum+=1
  print("Number of Character is: ",sum)

a=input('Enter a string: ')
count(a)
# Out:
# Enter a string: Mustakim Hero
# Number of Character is:  13

# %%
#Exercise 3
def per(val,perc):
  a=(val/perc)*100
  print(a)

a=int(input('Enetr the value: '))
b=int(input('Enter the Total Number: '))
per(a,b)
# Out:
# Enetr the value: 20
# Enter the Total Number: 100
# 20.0

# %%
#Exercise 4
def avg():
  a=int(input('Enter how mny number you want to get the average: '))
  sum=0
  for i in range(a):
    i=int(input('Enetr the number: '))
    sum+=i
  print(sum/a)
avg()
# Out:
# Enter how mny number you want to get the average: 3
# Enetr the number: 10
# Enetr the number: 20
# Enetr the number: 30
# 20.0

# %%
#Exercise 5
def validUsername(userName):
  if len(userName) >= 8 and len(userName) <=20:
    for char in userName:
      if char.isalnum():
        continue
      elif char == ' ':
        return 'Alert: Your userName contains white-space.'
      else:
        return 'Alert: Your userName contains special character'
    return 'Username is accepted'
  else:
    return 'Alert: Username should be 8-20 character'

string = input('Enter Username: ')
validUsername(string)
# Out:
# Enter Username: Mustakim
# 'Username is accepted'

# %%
addition = lambda a,b:a+b
print(addition(64,5))
# Out:
# 69

# %%
fn='Mustakim'
ln='Hossain'
print(f'First Name: {fn} and lAST Name: {ln}')
# Out:
# First Name: Mustakim and lAST Name: Hossain

# %%
#Lambda Exercise 1
fn=input('Enter the first name: ')
ln=input('Enter the last name: ')
name= lambda fn,ln:print(f'The first name is: {fn} and the last name is: {ln}')
name(fn,ln)
# Out:
# Enter the first name: my
# Enter the last name: name
# The first name is: my and the llast name is: name

# %%
#Exercise 2
addition = lambda a,b,c:a+b+c
m=int(input('Enter the first number: '))
n=int(input('Enter the second number: '))
o=int(input('Enter the third number: '))
print(addition(m,n,o))
# Out:
# Enter the first number: 4
# Enter the second number: 5
# Enter the third number: 6
# 15
